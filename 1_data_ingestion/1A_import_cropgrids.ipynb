# %%
# import modules
import os
import requests
import zipfile
import geopandas as gpd
import rasterio
from rasterio.mask import mask

# %%
# download cropgrids data

def download_data(url, save_path):
    """
    Downloads data from the specified URL and saves it to the given path.

    :param url: URL to download data from
    :param save_path: Path to save the downloaded data
    """
    try:
        # Send a GET request to the URL
        response = requests.get(url)
        response.raise_for_status()  # Raise an exception for HTTP errors

        # Check if the target folder exists, create if not
        if not os.path.exists(os.path.dirname(save_path)):
            os.makedirs(os.path.dirname(save_path))

        # Write the content to the file
        with open(save_path, 'wb') as file:
            file.write(response.content)
        
        print("Download completed successfully.")
    except requests.RequestException as e:
        print(f"An error occurred: {e}")

# URL and file path
url = "https://figshare.com/ndownloader/articles/22491997/versions/3"
file_path = r"C:\Users\djava\OneDrive\Documents\Oxford\Projects\india_rice_early_warning\4_data\RAW_DATA\CROPGRIDS\cropgrids.zip"

# Call the function
download_data(url, file_path)
# Out:
# Download completed successfully.

# %%
# unzip and delete

def unzip_and_delete(zip_file_path):
    """
    Unzips the specified ZIP file into the same directory and then deletes the ZIP file.

    :param zip_file_path: Path to the ZIP file
    """
    try:
        # Unzipping the file
        with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
            # Extract all the contents into the same directory as the zip file
            extract_path = os.path.dirname(zip_file_path)
            zip_ref.extractall(extract_path)
            print(f"Extracted to {extract_path}")

        # Deleting the original zip file
        os.remove(zip_file_path)
        print(f"Deleted the ZIP file: {zip_file_path}")

    except Exception as e:
        print(f"An error occurred: {e}")

# File path
zip_file_path = r"C:\Users\djava\OneDrive\Documents\Oxford\Projects\india_rice_early_warning\4_data\RAW_DATA\CROPGRIDS\cropgrids.zip"

# Call the function
unzip_and_delete(zip_file_path)
# Out:
# Extracted to C:\Users\djava\OneDrive\Documents\Oxford\Projects\india_rice_early_warning\4_data\RAW_DATA\CROPGRIDS
# Deleted the ZIP file: C:\Users\djava\OneDrive\Documents\Oxford\Projects\india_rice_early_warning\4_data\RAW_DATA\CROPGRIDS\cropgrids.zip

# %%
def unzip_and_delete(zip_to_unzip, file_to_delete, directory):
    """
    Unzips a specified ZIP file and deletes another specified file in the given directory.

    :param zip_to_unzip: Name of the ZIP file to unzip
    :param file_to_delete: Name of the file to delete
    :param directory: Directory where the files are located
    """
    try:
        # Full path of the zip file to unzip
        zip_file_path = os.path.join(directory, zip_to_unzip)

        # Unzipping the file
        with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
            zip_ref.extractall(directory)
            print(f"Extracted {zip_to_unzip}")

        # Full path of the file to delete
        file_to_delete_path = os.path.join(directory, file_to_delete)

        # Deleting the specified file
        if os.path.exists(file_to_delete_path):
            os.remove(file_to_delete_path)
            print(f"Deleted {file_to_delete}")
        else:
            print(f"File {file_to_delete} not found in the directory.")

    except Exception as e:
        print(f"An error occurred: {e}")

# Example usage
directory = r"C:\Users\djava\OneDrive\Documents\Oxford\Projects\india_rice_early_warning\4_data\RAW_DATA\CROPGRIDS"
unzip_file = "CROPGRIDSv1.06_NC_maps.zip"
delete_file = "CROPGRIDSv1.06_PNG_maps.zip"

unzip_and_delete(unzip_file, delete_file, directory)
# Out:
# Extracted CROPGRIDSv1.06_NC_maps.zip
# Deleted CROPGRIDSv1.06_PNG_maps.zip

# %%
import os

def clean_directory(keep_file, directory):
    """
    Deletes all files in the specified directory except the specified file to keep.

    :param keep_file: Name of the file to keep
    :param directory: Directory to clean
    """
    try:
        # Iterate through all files in the directory
        for filename in os.listdir(directory):
            file_path = os.path.join(directory, filename)
            # Check if it's a file and not the file we want to keep
            if os.path.isfile(file_path) and filename != keep_file:
                os.remove(file_path)
                print(f"Deleted {filename}")

        print("Directory cleaned, kept only the specified file.")

    except Exception as e:
        print(f"An error occurred: {e}")

# Example usage
directory = r"C:\Users\djava\OneDrive\Documents\Oxford\Projects\india_rice_early_warning\4_data\RAW_DATA\CROPGRIDS"
keep_file = "CROPGRIDSv1.06_rice.nc"

clean_directory(keep_file, directory)
# Out:
# Deleted Countries_2018.nc
# Deleted CROPGRIDSv1.06_abaca.nc
# Deleted CROPGRIDSv1.06_agave.nc
# Deleted CROPGRIDSv1.06_alfalfa.nc
# Deleted CROPGRIDSv1.06_almond.nc
# Deleted CROPGRIDSv1.06_aniseetc.nc
# Deleted CROPGRIDSv1.06_apple.nc
# Deleted CROPGRIDSv1.06_apricot.nc
# Deleted CROPGRIDSv1.06_areca.nc
# Deleted CROPGRIDSv1.06_artichoke.nc
# Deleted CROPGRIDSv1.06_asparagus.nc
# Deleted CROPGRIDSv1.06_avocado.nc
# Deleted CROPGRIDSv1.06_bambara.nc
# Deleted CROPGRIDSv1.06_banana.nc
# Deleted CROPGRIDSv1.06_barley.nc
# Deleted CROPGRIDSv1.06_bean.nc
# Deleted CROPGRIDSv1.06_beetfor.nc
# Deleted CROPGRIDSv1.06_berrynes.nc
# Deleted CROPGRIDSv1.06_blueberry.nc
# Deleted CROPGRIDSv1.06_brazil.nc
# Deleted CROPGRIDSv1.06_broadbean.nc
# Deleted CROPGRIDSv1.06_buckwheat.nc
# Deleted CROPGRIDSv1.06_cabbage.nc
# Deleted CROPGRIDSv1.06_cabbagefor.nc
# Deleted CROPGRIDSv1.06_canaryseed.nc
# Deleted CROPGRIDSv1.06_carob.nc
# Deleted CROPGRIDSv1.06_carrot.nc
# Deleted CROPGRIDSv1.06_carrotfor.nc
# Deleted CROPGRIDSv1.06_cashew.nc
# Deleted CROPGRIDSv1.06_cashewapple.nc
# Deleted CROPGRIDSv1.06_cassava.nc
# Deleted CROPGRIDSv1.06_castor.nc
# Deleted CROPGRIDSv1.06_cauliflower.nc
# Deleted CROPGRIDSv1.06_cerealnes.nc
# Deleted CROPGRIDSv1.06_cherry.nc
# Deleted CROPGRIDSv1.06_chestnut.nc
# Deleted CROPGRIDSv1.06_chickpea.nc
# Deleted CROPGRIDSv1.06_chicory.nc
# Deleted CROPGRIDSv1.06_chilleetc.nc
# Deleted CROPGRIDSv1.06_cinnamon.nc
# Deleted CROPGRIDSv1.06_citrusnes.nc
# Deleted CROPGRIDSv1.06_clove.nc
# Deleted CROPGRIDSv1.06_clover.nc
# Deleted CROPGRIDSv1.06_cocoa.nc
# Deleted CROPGRIDSv1.06_coconut.nc
# Deleted CROPGRIDSv1.06_coffee.nc
# Deleted CROPGRIDSv1.06_coir.nc
# Deleted CROPGRIDSv1.06_cotton.nc
# Deleted CROPGRIDSv1.06_cowpea.nc
# Deleted CROPGRIDSv1.06_cranberry.nc
# Deleted CROPGRIDSv1.06_cucumberetc.nc
# Deleted CROPGRIDSv1.06_currant.nc
# Deleted CROPGRIDSv1.06_date.nc
# Deleted CROPGRIDSv1.06_eggplant.nc
# Deleted CROPGRIDSv1.06_fibrenes.nc
# Deleted CROPGRIDSv1.06_fig.nc
# Deleted CROPGRIDSv1.06_flax.nc
# Deleted CROPGRIDSv1.06_fonio.nc
# Deleted CROPGRIDSv1.06_fornes.nc
# Deleted CROPGRIDSv1.06_fruitnes.nc
# Deleted CROPGRIDSv1.06_garlic.nc
# Deleted CROPGRIDSv1.06_ginger.nc
# Deleted CROPGRIDSv1.06_gooseberry.nc
# Deleted CROPGRIDSv1.06_grape.nc
# Deleted CROPGRIDSv1.06_grapefruitetc.nc
# Deleted CROPGRIDSv1.06_grassnes.nc
# Deleted CROPGRIDSv1.06_greenbean.nc
# Deleted CROPGRIDSv1.06_greenbroadbean.nc
# Deleted CROPGRIDSv1.06_greencorn.nc
# Deleted CROPGRIDSv1.06_greenonion.nc
# Deleted CROPGRIDSv1.06_greenpea.nc
# Deleted CROPGRIDSv1.06_groundnut.nc
# Deleted CROPGRIDSv1.06_gums.nc
# Deleted CROPGRIDSv1.06_hazelnut.nc
# Deleted CROPGRIDSv1.06_hemp.nc
# Deleted CROPGRIDSv1.06_hempseed.nc
# Deleted CROPGRIDSv1.06_hop.nc
# Deleted CROPGRIDSv1.06_jute.nc
# Deleted CROPGRIDSv1.06_jutelikefiber.nc
# Deleted CROPGRIDSv1.06_kapokfiber.nc
# Deleted CROPGRIDSv1.06_kapokseed.nc
# Deleted CROPGRIDSv1.06_karite.nc
# Deleted CROPGRIDSv1.06_kiwi.nc
# Deleted CROPGRIDSv1.06_kolanut.nc
# Deleted CROPGRIDSv1.06_legumenes.nc
# Deleted CROPGRIDSv1.06_lemonlime.nc
# Deleted CROPGRIDSv1.06_lentil.nc
# Deleted CROPGRIDSv1.06_lettuce.nc
# Deleted CROPGRIDSv1.06_linseed.nc
# Deleted CROPGRIDSv1.06_lupin.nc
# Deleted CROPGRIDSv1.06_maize.nc
# Deleted CROPGRIDSv1.06_maizefor.nc
# Deleted CROPGRIDSv1.06_mango.nc
# Deleted CROPGRIDSv1.06_mate.nc
# Deleted CROPGRIDSv1.06_melonetc.nc
# Deleted CROPGRIDSv1.06_melonseed.nc
# Deleted CROPGRIDSv1.06_millet.nc
# Deleted CROPGRIDSv1.06_mixedgrain.nc
# Deleted CROPGRIDSv1.06_mixedgrass.nc
# Deleted CROPGRIDSv1.06_mushroom.nc
# Deleted CROPGRIDSv1.06_mustard.nc
# Deleted CROPGRIDSv1.06_NC_maps.zip
# Deleted CROPGRIDSv1.06_nutmeg.nc
# Deleted CROPGRIDSv1.06_nutnes.nc
# Deleted CROPGRIDSv1.06_oats.nc
# Deleted CROPGRIDSv1.06_oilpalm.nc
# Deleted CROPGRIDSv1.06_oilseedfor.nc
# Deleted CROPGRIDSv1.06_oilseednes.nc
# Deleted CROPGRIDSv1.06_okra.nc
# Deleted CROPGRIDSv1.06_olive.nc
# Deleted CROPGRIDSv1.06_onion.nc
# Deleted CROPGRIDSv1.06_orange.nc
# Deleted CROPGRIDSv1.06_papaya.nc
# Deleted CROPGRIDSv1.06_pea.nc
# Deleted CROPGRIDSv1.06_peachetc.nc
# Deleted CROPGRIDSv1.06_pear.nc
# Deleted CROPGRIDSv1.06_pepper.nc
# Deleted CROPGRIDSv1.06_peppermint.nc
# Deleted CROPGRIDSv1.06_persimmon.nc
# Deleted CROPGRIDSv1.06_pigeonpea.nc
# Deleted CROPGRIDSv1.06_pimento.nc
# Deleted CROPGRIDSv1.06_pineapple.nc
# Deleted CROPGRIDSv1.06_pistachio.nc
# Deleted CROPGRIDSv1.06_plantain.nc
# Deleted CROPGRIDSv1.06_plum.nc
# Deleted CROPGRIDSv1.06_popcorn.nc
# Deleted CROPGRIDSv1.06_poppy.nc
# Deleted CROPGRIDSv1.06_potato.nc
# Deleted CROPGRIDSv1.06_pulsenes.nc
# Deleted CROPGRIDSv1.06_pumpkinetc.nc
# Deleted CROPGRIDSv1.06_pyrethrum.nc
# Deleted CROPGRIDSv1.06_quince.nc
# Deleted CROPGRIDSv1.06_quinoa.nc
# Deleted CROPGRIDSv1.06_ramie.nc
# Deleted CROPGRIDSv1.06_rapeseed.nc
# Deleted CROPGRIDSv1.06_rasberry.nc
# Deleted CROPGRIDSv1.06_rootnes.nc
# Deleted CROPGRIDSv1.06_rubber.nc
# Deleted CROPGRIDSv1.06_rye.nc
# Deleted CROPGRIDSv1.06_ryefor.nc
# Deleted CROPGRIDSv1.06_safflower.nc
# Deleted CROPGRIDSv1.06_sesame.nc
# Deleted CROPGRIDSv1.06_sisal.nc
# Deleted CROPGRIDSv1.06_sorghum.nc
# Deleted CROPGRIDSv1.06_sorghumfor.nc
# Deleted CROPGRIDSv1.06_sourcherry.nc
# Deleted CROPGRIDSv1.06_soybean.nc
# Deleted CROPGRIDSv1.06_spicenes.nc
# Deleted CROPGRIDSv1.06_spinach.nc
# Deleted CROPGRIDSv1.06_stonefruitnes.nc
# Deleted CROPGRIDSv1.06_strawberry.nc
# Deleted CROPGRIDSv1.06_stringbean.nc
# Deleted CROPGRIDSv1.06_sugarbeet.nc
# Deleted CROPGRIDSv1.06_sugarcane.nc
# Deleted CROPGRIDSv1.06_sugarnes.nc
# Deleted CROPGRIDSv1.06_sunflower.nc
# Deleted CROPGRIDSv1.06_swedefor.nc
# Deleted CROPGRIDSv1.06_sweetpotato.nc
# Deleted CROPGRIDSv1.06_tangetc.nc
# Deleted CROPGRIDSv1.06_taro.nc
# Deleted CROPGRIDSv1.06_tea.nc
# Deleted CROPGRIDSv1.06_tobacco.nc
# Deleted CROPGRIDSv1.06_tomato.nc
# Deleted CROPGRIDSv1.06_triticale.nc
# Deleted CROPGRIDSv1.06_tropicalnes.nc
# Deleted CROPGRIDSv1.06_tung.nc
# Deleted CROPGRIDSv1.06_turnipfor.nc
# Deleted CROPGRIDSv1.06_vanilla.nc
# Deleted CROPGRIDSv1.06_vegetablenes.nc
# Deleted CROPGRIDSv1.06_vegfor.nc
# Deleted CROPGRIDSv1.06_vetch.nc
# Deleted CROPGRIDSv1.06_walnut.nc
# Deleted CROPGRIDSv1.06_watermelon.nc
# Deleted CROPGRIDSv1.06_wheat.nc
# Deleted CROPGRIDSv1.06_yam.nc
# Deleted CROPGRIDSv1.06_yautia.nc
# Deleted CROPGRIDS_Dataset_Distribution.pdf
# Deleted Table_CROPGRIDS_COU.xlsx
# Directory cleaned, kept only the specified file.
