# %%
# check installed version (must be >3.0)
import pycaret
pycaret.__version__
# Out:
# '3.2.0'

# %%
### load sample dataset from pycaret dataset module
from pycaret.datasets import get_data
data = get_data('insurance')
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
# import pycaret regression and init setup
from pycaret.regression import *
s = setup(data, target = 'charges', session_id = 123)
# Out:
# <style type="text/css">
# #T_c110a_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_c110a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c110a_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_c110a_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c110a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c110a_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_c110a_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_c110a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c110a_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_c110a_row1_col1" class="data row1 col1" >charges</td>
#     </tr>
#     <tr>
#       <th id="T_c110a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c110a_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_c110a_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_c110a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c110a_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_c110a_row3_col1" class="data row3 col1" >(1338, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_c110a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c110a_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_c110a_row4_col1" class="data row4 col1" >(1338, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_c110a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c110a_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_c110a_row5_col1" class="data row5 col1" >(936, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_c110a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c110a_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_c110a_row6_col1" class="data row6 col1" >(402, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_c110a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c110a_row7_col0" class="data row7 col0" >Ordinal features</td>
#       <td id="T_c110a_row7_col1" class="data row7 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_c110a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c110a_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_c110a_row8_col1" class="data row8 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_c110a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c110a_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_c110a_row9_col1" class="data row9 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_c110a_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_c110a_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_c110a_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c110a_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_c110a_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_c110a_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_c110a_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_c110a_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_c110a_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_c110a_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_c110a_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_c110a_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_c110a_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_c110a_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_c110a_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_c110a_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_c110a_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_c110a_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_c110a_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_c110a_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_c110a_row16_col1" class="data row16 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_c110a_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_c110a_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_c110a_row17_col1" class="data row17 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_c110a_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_c110a_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_c110a_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_c110a_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_c110a_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_c110a_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c110a_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_c110a_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_c110a_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c110a_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_c110a_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_c110a_row21_col1" class="data row21 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_c110a_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_c110a_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_c110a_row22_col1" class="data row22 col1" >44fc</td>
#     </tr>
#   </tbody>
# </table>

# %%
# import RegressionExperiment and init the class
from pycaret.regression import RegressionExperiment
exp = RegressionExperiment()

# %%
# check the type of exp
type(exp)
# Out:
# pycaret.regression.oop.RegressionExperiment

# %%
# init setup on exp
exp.setup(data, target = 'charges', session_id = 123)
# Out:
# <style type="text/css">
# #T_21090_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_21090">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_21090_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_21090_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_21090_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_21090_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_21090_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_21090_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_21090_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_21090_row1_col1" class="data row1 col1" >charges</td>
#     </tr>
#     <tr>
#       <th id="T_21090_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_21090_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_21090_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_21090_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_21090_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_21090_row3_col1" class="data row3 col1" >(1338, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_21090_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_21090_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_21090_row4_col1" class="data row4 col1" >(1338, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_21090_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_21090_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_21090_row5_col1" class="data row5 col1" >(936, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_21090_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_21090_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_21090_row6_col1" class="data row6 col1" >(402, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_21090_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_21090_row7_col0" class="data row7 col0" >Ordinal features</td>
#       <td id="T_21090_row7_col1" class="data row7 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_21090_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_21090_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_21090_row8_col1" class="data row8 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_21090_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_21090_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_21090_row9_col1" class="data row9 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_21090_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_21090_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_21090_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_21090_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_21090_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_21090_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_21090_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_21090_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_21090_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_21090_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_21090_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_21090_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_21090_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_21090_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_21090_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_21090_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_21090_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_21090_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_21090_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_21090_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_21090_row16_col1" class="data row16 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_21090_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_21090_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_21090_row17_col1" class="data row17 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_21090_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_21090_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_21090_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_21090_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_21090_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_21090_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_21090_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_21090_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_21090_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_21090_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_21090_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_21090_row21_col1" class="data row21 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_21090_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_21090_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_21090_row22_col1" class="data row22 col1" >2948</td>
#     </tr>
#   </tbody>
# </table>

# %%
# compare baseline models
best = compare_models()
# Out:
# <style type="text/css">
# #T_6a667 th {
#   text-align: left;
# }
# #T_6a667_row0_col0, #T_6a667_row0_col6, #T_6a667_row1_col0, #T_6a667_row1_col1, #T_6a667_row1_col2, #T_6a667_row1_col3, #T_6a667_row1_col4, #T_6a667_row1_col5, #T_6a667_row1_col6, #T_6a667_row2_col0, #T_6a667_row2_col1, #T_6a667_row2_col2, #T_6a667_row2_col3, #T_6a667_row2_col4, #T_6a667_row2_col5, #T_6a667_row2_col6, #T_6a667_row3_col0, #T_6a667_row3_col1, #T_6a667_row3_col2, #T_6a667_row3_col3, #T_6a667_row3_col4, #T_6a667_row3_col5, #T_6a667_row3_col6, #T_6a667_row4_col0, #T_6a667_row4_col1, #T_6a667_row4_col2, #T_6a667_row4_col3, #T_6a667_row4_col4, #T_6a667_row4_col5, #T_6a667_row4_col6, #T_6a667_row5_col0, #T_6a667_row5_col1, #T_6a667_row5_col2, #T_6a667_row5_col3, #T_6a667_row5_col4, #T_6a667_row5_col5, #T_6a667_row5_col6, #T_6a667_row6_col0, #T_6a667_row6_col1, #T_6a667_row6_col2, #T_6a667_row6_col3, #T_6a667_row6_col4, #T_6a667_row6_col5, #T_6a667_row6_col6, #T_6a667_row7_col0, #T_6a667_row7_col1, #T_6a667_row7_col2, #T_6a667_row7_col3, #T_6a667_row7_col4, #T_6a667_row7_col5, #T_6a667_row7_col6, #T_6a667_row8_col0, #T_6a667_row8_col1, #T_6a667_row8_col2, #T_6a667_row8_col3, #T_6a667_row8_col4, #T_6a667_row8_col5, #T_6a667_row8_col6, #T_6a667_row9_col0, #T_6a667_row9_col1, #T_6a667_row9_col2, #T_6a667_row9_col3, #T_6a667_row9_col4, #T_6a667_row9_col5, #T_6a667_row9_col6, #T_6a667_row10_col0, #T_6a667_row10_col1, #T_6a667_row10_col2, #T_6a667_row10_col3, #T_6a667_row10_col4, #T_6a667_row10_col5, #T_6a667_row10_col6, #T_6a667_row11_col0, #T_6a667_row11_col1, #T_6a667_row11_col2, #T_6a667_row11_col3, #T_6a667_row11_col4, #T_6a667_row11_col5, #T_6a667_row12_col0, #T_6a667_row12_col1, #T_6a667_row12_col2, #T_6a667_row12_col3, #T_6a667_row12_col4, #T_6a667_row12_col5, #T_6a667_row12_col6, #T_6a667_row13_col0, #T_6a667_row13_col1, #T_6a667_row13_col2, #T_6a667_row13_col3, #T_6a667_row13_col4, #T_6a667_row13_col5, #T_6a667_row13_col6, #T_6a667_row14_col0, #T_6a667_row14_col1, #T_6a667_row14_col2, #T_6a667_row14_col3, #T_6a667_row14_col4, #T_6a667_row14_col5, #T_6a667_row14_col6, #T_6a667_row15_col0, #T_6a667_row15_col1, #T_6a667_row15_col2, #T_6a667_row15_col3, #T_6a667_row15_col4, #T_6a667_row15_col5, #T_6a667_row15_col6, #T_6a667_row16_col0, #T_6a667_row16_col1, #T_6a667_row16_col2, #T_6a667_row16_col3, #T_6a667_row16_col4, #T_6a667_row16_col5, #T_6a667_row16_col6, #T_6a667_row17_col0, #T_6a667_row17_col1, #T_6a667_row17_col2, #T_6a667_row17_col3, #T_6a667_row17_col4, #T_6a667_row17_col5, #T_6a667_row17_col6 {
#   text-align: left;
# }
# #T_6a667_row0_col1, #T_6a667_row0_col2, #T_6a667_row0_col3, #T_6a667_row0_col4, #T_6a667_row0_col5, #T_6a667_row11_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_6a667_row0_col7, #T_6a667_row1_col7, #T_6a667_row2_col7, #T_6a667_row3_col7, #T_6a667_row4_col7, #T_6a667_row5_col7, #T_6a667_row6_col7, #T_6a667_row7_col7, #T_6a667_row8_col7, #T_6a667_row9_col7, #T_6a667_row10_col7, #T_6a667_row11_col7, #T_6a667_row12_col7, #T_6a667_row13_col7, #T_6a667_row14_col7, #T_6a667_row16_col7, #T_6a667_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_6a667_row15_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_6a667">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6a667_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_6a667_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_6a667_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_6a667_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_6a667_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_6a667_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_6a667_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_6a667_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6a667_level0_row0" class="row_heading level0 row0" >gbr</th>
#       <td id="T_6a667_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_6a667_row0_col1" class="data row0 col1" >2701.9919</td>
#       <td id="T_6a667_row0_col2" class="data row0 col2" >23548657.1177</td>
#       <td id="T_6a667_row0_col3" class="data row0 col3" >4832.9329</td>
#       <td id="T_6a667_row0_col4" class="data row0 col4" >0.8320</td>
#       <td id="T_6a667_row0_col5" class="data row0 col5" >0.4447</td>
#       <td id="T_6a667_row0_col6" class="data row0 col6" >0.3137</td>
#       <td id="T_6a667_row0_col7" class="data row0 col7" >0.0310</td>
#     </tr>
#     <tr>
#       <th id="T_6a667_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_6a667_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_6a667_row1_col1" class="data row1 col1" >2771.4583</td>
#       <td id="T_6a667_row1_col2" class="data row1 col2" >25416502.3827</td>
#       <td id="T_6a667_row1_col3" class="data row1 col3" >5028.6343</td>
#       <td id="T_6a667_row1_col4" class="data row1 col4" >0.8172</td>
#       <td id="T_6a667_row1_col5" class="data row1 col5" >0.4690</td>
#       <td id="T_6a667_row1_col6" class="data row1 col6" >0.3303</td>
#       <td id="T_6a667_row1_col7" class="data row1 col7" >0.0640</td>
#     </tr>
#     <tr>
#       <th id="T_6a667_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_6a667_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_6a667_row2_col1" class="data row2 col1" >2992.1828</td>
#       <td id="T_6a667_row2_col2" class="data row2 col2" >25521038.3331</td>
#       <td id="T_6a667_row2_col3" class="data row2 col3" >5042.0978</td>
#       <td id="T_6a667_row2_col4" class="data row2 col4" >0.8149</td>
#       <td id="T_6a667_row2_col5" class="data row2 col5" >0.5378</td>
#       <td id="T_6a667_row2_col6" class="data row2 col6" >0.3751</td>
#       <td id="T_6a667_row2_col7" class="data row2 col7" >0.1740</td>
#     </tr>
#     <tr>
#       <th id="T_6a667_level0_row3" class="row_heading level0 row3" >et</th>
#       <td id="T_6a667_row3_col0" class="data row3 col0" >Extra Trees Regressor</td>
#       <td id="T_6a667_row3_col1" class="data row3 col1" >2833.3624</td>
#       <td id="T_6a667_row3_col2" class="data row3 col2" >28427844.2412</td>
#       <td id="T_6a667_row3_col3" class="data row3 col3" >5305.6516</td>
#       <td id="T_6a667_row3_col4" class="data row3 col4" >0.7991</td>
#       <td id="T_6a667_row3_col5" class="data row3 col5" >0.4877</td>
#       <td id="T_6a667_row3_col6" class="data row3 col6" >0.3363</td>
#       <td id="T_6a667_row3_col7" class="data row3 col7" >0.0570</td>
#     </tr>
#     <tr>
#       <th id="T_6a667_level0_row4" class="row_heading level0 row4" >ada</th>
#       <td id="T_6a667_row4_col0" class="data row4 col0" >AdaBoost Regressor</td>
#       <td id="T_6a667_row4_col1" class="data row4 col1" >4316.0568</td>
#       <td id="T_6a667_row4_col2" class="data row4 col2" >29220505.6498</td>
#       <td id="T_6a667_row4_col3" class="data row4 col3" >5398.4561</td>
#       <td id="T_6a667_row4_col4" class="data row4 col4" >0.7903</td>
#       <td id="T_6a667_row4_col5" class="data row4 col5" >0.6368</td>
#       <td id="T_6a667_row4_col6" class="data row4 col6" >0.7394</td>
#       <td id="T_6a667_row4_col7" class="data row4 col7" >0.0180</td>
#     </tr>
#     <tr>
#       <th id="T_6a667_level0_row5" class="row_heading level0 row5" >lar</th>
#       <td id="T_6a667_row5_col0" class="data row5 col0" >Least Angle Regression</td>
#       <td id="T_6a667_row5_col1" class="data row5 col1" >4303.5559</td>
#       <td id="T_6a667_row5_col2" class="data row5 col2" >38388058.4578</td>
#       <td id="T_6a667_row5_col3" class="data row5 col3" >6176.5920</td>
#       <td id="T_6a667_row5_col4" class="data row5 col4" >0.7306</td>
#       <td id="T_6a667_row5_col5" class="data row5 col5" >0.5949</td>
#       <td id="T_6a667_row5_col6" class="data row5 col6" >0.4433</td>
#       <td id="T_6a667_row5_col7" class="

# %%
# plot residuals
plot_model(best, plot = 'residuals')

# %%
# plot error
plot_model(best, plot = 'error')

# %%
# train lightgbm model
lightgbm = create_model('lightgbm')
# Out:
# <style type="text/css">
# #T_5f9ee_row10_col0, #T_5f9ee_row10_col1, #T_5f9ee_row10_col2, #T_5f9ee_row10_col3, #T_5f9ee_row10_col4, #T_5f9ee_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_5f9ee">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5f9ee_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_5f9ee_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_5f9ee_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_5f9ee_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_5f9ee_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_5f9ee_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5f9ee_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5f9ee_row0_col0" class="data row0 col0" >2896.4964</td>
#       <td id="T_5f9ee_row0_col1" class="data row0 col1" >23611929.4013</td>
#       <td id="T_5f9ee_row0_col2" class="data row0 col2" >4859.2108</td>
#       <td id="T_5f9ee_row0_col3" class="data row0 col3" >0.8590</td>
#       <td id="T_5f9ee_row0_col4" class="data row0 col4" >0.5993</td>
#       <td id="T_5f9ee_row0_col5" class="data row0 col5" >0.3808</td>
#     </tr>
#     <tr>
#       <th id="T_5f9ee_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5f9ee_row1_col0" class="data row1 col0" >3075.9419</td>
#       <td id="T_5f9ee_row1_col1" class="data row1 col1" >30047230.7486</td>
#       <td id="T_5f9ee_row1_col2" class="data row1 col2" >5481.5354</td>
#       <td id="T_5f9ee_row1_col3" class="data row1 col3" >0.8253</td>
#       <td id="T_5f9ee_row1_col4" class="data row1 col4" >0.4622</td>
#       <td id="T_5f9ee_row1_col5" class="data row1 col5" >0.3295</td>
#     </tr>
#     <tr>
#       <th id="T_5f9ee_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5f9ee_row2_col0" class="data row2 col0" >3090.7426</td>
#       <td id="T_5f9ee_row2_col1" class="data row2 col1" >27877897.1696</td>
#       <td id="T_5f9ee_row2_col2" class="data row2 col2" >5279.9524</td>
#       <td id="T_5f9ee_row2_col3" class="data row2 col3" >0.6470</td>
#       <td id="T_5f9ee_row2_col4" class="data row2 col4" >0.6213</td>
#       <td id="T_5f9ee_row2_col5" class="data row2 col5" >0.4468</td>
#     </tr>
#     <tr>
#       <th id="T_5f9ee_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5f9ee_row3_col0" class="data row3 col0" >3247.8918</td>
#       <td id="T_5f9ee_row3_col1" class="data row3 col1" >26531240.5577</td>
#       <td id="T_5f9ee_row3_col2" class="data row3 col2" >5150.8485</td>
#       <td id="T_5f9ee_row3_col3" class="data row3 col3" >0.7785</td>
#       <td id="T_5f9ee_row3_col4" class="data row3 col4" >0.7497</td>
#       <td id="T_5f9ee_row3_col5" class="data row3 col5" >0.5276</td>
#     </tr>
#     <tr>
#       <th id="T_5f9ee_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5f9ee_row4_col0" class="data row4 col0" >3263.7660</td>
#       <td id="T_5f9ee_row4_col1" class="data row4 col1" >29391206.7843</td>
#       <td id="T_5f9ee_row4_col2" class="data row4 col2" >5421.3658</td>
#       <td id="T_5f9ee_row4_col3" class="data row4 col3" >0.7814</td>
#       <td id="T_5f9ee_row4_col4" class="data row4 col4" >0.5628</td>
#       <td id="T_5f9ee_row4_col5" class="data row4 col5" >0.3846</td>
#     </tr>
#     <tr>
#       <th id="T_5f9ee_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5f9ee_row5_col0" class="data row5 col0" >2930.1800</td>
#       <td id="T_5f9ee_row5_col1" class="data row5 col1" >21751409.5632</td>
#       <td id="T_5f9ee_row5_col2" class="data row5 col2" >4663.8406</td>
#       <td id="T_5f9ee_row5_col3" class="data row5 col3" >0.8601</td>
#       <td id="T_5f9ee_row5_col4" class="data row5 col4" >0.4058</td>
#       <td id="T_5f9ee_row5_col5" class="data row5 col5" >0.2873</td>
#     </tr>
#     <tr>
#       <th id="T_5f9ee_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5f9ee_row6_col0" class="data row6 col0" >2733.8071</td>
#       <td id="T_5f9ee_row6_col1" class="data row6 col1" >21012815.3865</td>
#       <td id="T_5f9ee_row6_col2" class="data row6 col2" >4583.9738</td>
#       <td id="T_5f9ee_row6_col3" class="data row6 col3" >0.8570</td>
#       <td id="T_5f9ee_row6_col4" class="data row6 col4" >0.3991</td>
#       <td id="T_5f9ee_row6_col5" class="data row6 col5" >0.3139</td>
#     </tr>
#     <tr>
#       <th id="T_5f9ee_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5f9ee_row7_col0" class="data row7 col0" >2865.5796</td>
#       <td id="T_5f9ee_row7_col1" class="data row7 col1" >25843408.7132</td>
#       <td id="T_5f9ee_row7_col2" class="data row7 col2" >5083.6413</td>
#       <td id="T_5f9ee_row7_col3" class="data row7 col3" >0.8579</td>
#       <td id="T_5f9ee_row7_col4" class="data row7 col4" >0.5027</td>
#       <td id="T_5f9ee_row7_col5" class="data row7 col5" >0.2995</td>
#     </tr>
#     <tr>
#       <th id="T_5f9ee_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5f9ee_row8_col0" class="data row8 col0" >2715.5680</td>
#       <td id="T_5f9ee_row8_col1" class="data row8 col1" >21671018.5929</td>
#       <td id="T_5f9ee_row8_col2" class="data row8 col2" >4655.2141</td>
#       <td id="T_5f9ee_row8_col3" class="data row8 col3" >0.8600</td>
#       <td id="T_5f9ee_row8_col4" class="data row8 col4" >0.5233</td>
#       <td id="T_5f9ee_row8_col5" class="data row8 col5" >0.4192</td>
#     </tr>
#     <tr>
#       <th id="T_5f9ee_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5f9ee_row9_col0" class="data row9 col0" >3101.8547</td>
#       <td id="T_5f9ee_row9_col1" class="data row9 col1" >27472226.4139</td>
#       <td id="T_5f9ee_row9_col2" class="data row9 col2" >5241.3955</td>
#       <td id="T_5f9ee_row9_col3" class="data row9 col3" >0.8230</td>
#       <td id="T_5f9ee_row9_col4" class="data row9 col4" >0.5521</td>
#       <td id="T_5f9ee_row9_col5" class="data row9 col5" >0.3621</td>
#     </tr>
#     <tr>
#       <th id="T_5f9ee_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_5f9ee_row10_col0" class="data row10 col0" >2992.1828</td>
#       <td id="T_5f9ee_row10_col1" class="data row10 col1" >25521038.3331</td>
#       <td id="T_5f9ee_row10_col2" class="data row10 col2" >5042.0978</td>
#       <td id="T_5f9ee_row10_col3" class="data row10 col3" >0.8149</td>
#       <td id="T_5f9ee_row10_col4" class="data row10 col4" >0.5378</td>
#       <td id="T_5f9ee_row10_col5" class="data row10 col5" >0.3751</td>
#     </tr>
#     <tr>
#       <th id="T_5f9ee_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_5f9ee_row11_col0" class="data row11 col0" >184.4463</td>
#       <td id="T_5f9ee_row11_col1" class="data row11 col1" >3145671.5568</td>
#       <td id="T_5f9ee_row11_col2" class="data row11 col2" >313.5091</td>
#       <td id="T_5f9ee_row11_col3" class="data row11 col3" >0.0636</td>
#       <td id="T_5f9ee_row11_col4" class="data row11 col4" >0.1002</td>
#       <td id="T_5f9ee_row11_col5" class="data row11 col5" >0.0706</td>
#     </tr>
#   </tbody>
# </table>

# %%
# interpret summary model
interpret_model(lightgbm, plot = 'summary')

# %%
import shap

# %%
# interpret summary model
interpret_model(lightgbm, plot = 'summary')

# %%
# reason plot for test set observation 1
interpret_model(lightgbm, plot = 'reason', observation = 1)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# <div id='i6XJYC8Q2BOXIM8QJCYF9'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 13225.43524383393, "outValue": 9479.902222294593, "link": "identity", "featureNames": ["age", "sex", "bmi", "children", "smoker", "region_northeast", "region_southwest", "region_southeast", "region_northwest"], "features": {"0": {"effect": -2353.0863448831274, "value": 32.0}, "1": {"effect": -108.71090191764328, "value": 1.0}, "2": {"effect": 952.228801782097, "value": 37.334999084472656}, "3": {"effect": 1447.9776691528643, "value": 1.0}, "4": {"effect": -5759.441686372841, "value": 0.0}, "5": {"effect": 1973.4290240364408, "value": 1.0}, "6": {"effect": 69.32917185209199, "value": 0.0}, "7": {"effect": 153.71045390505873, "value": 0.0}, "8": {"effect": -120.96920909427759, "value": 0.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('i6XJYC8Q2BOXIM8QJCYF9')
#   );
# </script>
